# %%
import requests

# Example function to fetch data from the API
def fetch_data(api_url):
    try:
        response = requests.get(api_url)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Example usage for the corrected API endpoint
url = 'https://data.edmonton.ca/resource/k4tx-5k8p.json?$query=SELECT%20disruption_id%2C%20date_issued%2C%20start_date%2C%20finish_date%2C%20status%2C%20closure%2C%20on_street%2C%20from_street%2C%20to_street%2C%20impact%2C%20duration%2C%20details%2C%20description%2C%20activity_type%2C%20traffic_district%2C%20infrastructure%2C%20point%20ORDER%20BY%20:id%20ASC'
data = fetch_data(url)

print(data)
# Out:
# [{'disruption_id': '32', 'date_issued': '2022-06-14T00:00:00.000', 'start_date': '2022-06-20T00:00:00.000', 'finish_date': '2024-06-20T00:00:00.000', 'status': 'Current', 'closure': 'Stony Plain Rd/149 St Reduced to 1 Lane Each W', 'on_street': 'Stony Plain Road', 'from_street': '139 Street NW', 'to_street': '157 Street NW', 'impact': 'Travel Delays', 'duration': '2 Years', 'details': 'Stony Plain Rd, from 139 St - 157 St, and 149 St, from 100 Av - 102 Av, will be reduced to 1 lane in each direction for LRT construction work. Use other routes. Various sidewalk closures will also be required for this and pedestrians will be detoured.', 'description': 'WLRT Construction', 'activity_type': 'Construction', 'traffic_district': 'Northeast', 'infrastructure': 'Road', 'point': {'type': 'Point', 'coordinates': [-113.592080656202, 53.541294164135]}}, {'disruption_id': '34', 'date_issued': '2022-05-20T00:00:00.000', 'start_date': '2022-05-20T00:00:00.000', 'finish_date': '2024-05-20T00:00:00.000', 'status': 'Current', 'closure': '156 St/Meadowlark Rd Reduced to 1 Lane Each Way', 'on_street': '156 Street NW', 'from_street': 'Stony Plain Road', 'to_street': '87 Avenue NW', 'impact': 'Travel Delays', 'duration': '2 Years', 'details': '156 St/Meadowlark Rd will be reduced to 1 lane in each directon from Stony Plain Rd to 87 Av in various stages for LRT construction. Use other routes. Sidewalk closures will take place on one side of 156 St at a time.', 'description': 'LRT Construction', 'activity_type': 'Construction', 'traffic_district': 'Northwest', 'infrastructure': 'Road and Sidewalk', 'point': {'type': 'Point', 'coordinates': [-113.590332225448, 53.519453481099]}}, {'disruption_id': '33', 'date_issued': '2022-06-03T00:00:00.000', 'start_date': '2022-04-19T00:00:00.000', 'finish_date': '2024-04-19T00:00:00.000', 'status': 'Current', 'closure': '87 Av Reduced to 1 Lane Each Way', 'on_street': '87 Avenue NW', 'from_street': '159 Street NW', 'to_street': '182 Street NW', 'impact': 'Travel Delays', 'duration': '2 Years', 'details': '87 Av will be reduced to 1 lane in each direction in various phases from 159 St to 189 St. Use other routes.', 'description': 'LRT Construction', 'activity_type': 'Construction', 'traffic_district': 'Northwest', 'infrastructure': 'Road', 'point': {'type': 'Point', 'coordinates': [-113.637149749965, 53.521606230676]}}, {'disruption_id': '34', 'date_issued': '2022-05-20T00:00:00.000', 'start_date': '2022-05-20T00:00:00.000', 'finish_date': '2024-05-20T00:00:00.000', 'status': 'Current', 'closure': '156 St/Meadowlark Rd Reduced to 1 Lane Each Way', 'on_street': '156 Street NW', 'from_street': 'Stony Plain Road', 'to_street': '87 Avenue NW', 'impact': 'Travel Delays', 'duration': '2 Years', 'details': '156 St/Meadowlark Rd will be reduced to 1 lane in each directon from Stony Plain Rd to 87 Av in various stages for LRT construction. Use other routes. Sidewalk closures will take place on one side of 156 St at a time.', 'description': 'LRT Construction', 'activity_type': 'Construction', 'traffic_district': 'Northwest', 'infrastructure': 'Road and Sidewalk', 'point': {'type': 'Point', 'coordinates': [-113.590326243448, 53.5412931906]}}, {'disruption_id': '37', 'date_issued': '2022-01-17T00:00:00.000', 'start_date': '2021-07-27T00:00:00.000', 'finish_date': '2024-12-31T00:00:00.000', 'status': 'Current', 'closure': '87 Ave West LRT Construction', 'on_street': '87 Avenue NW', 'from_street': '170 Street NW', 'to_street': '175 Street NW', 'impact': 'Travel Delays', 'duration': '3 Years', 'details': 'The right lane of WB 87 Ave will remain closed from 170 St - 175 St for the West LRT construction project. There will be various impacts to sidewalks and mall accesses as work progresses. Additional lane closures will follow with separate or revised TDNs.', 'description': 'West LRT Construction', 'activity_type': 'Construction', 'traffic_district': 'Northwest', 'infrastructure': 'Road and Sidewalk', 'point': {'type': 'Point', 'co ...

# %%
import pandas as pd
traffic_df = pd.DataFrame(data)
# Set 'disruption_id' as the index
traffic_df.set_index('disruption_id', inplace=True)
traffic_df.head(5)
# Out:
#                            date_issued               start_date  \
# disruption_id
# 32             2022-06-14T00:00:00.000  2022-06-20T00:00:00.000
# 34             2022-05-20T00:00:00.000  2022-05-20T00:00:00.000
# 33             2022-06-03T00:00:00.000  2022-04-19T00:00:00.000
# 34             2022-05-20T00:00:00.000  2022-05-20T00:00:00.000
# 37             2022-01-17T00:00:00.000  2021-07-27T00:00:00.000
#
#                            finish_date   status  \
# disruption_id
# 32             2024-06-20T00:00:00.000  Current
# 34             2024-05-20T00:00:00.000  Current
# 33             2024-04-19T00:00:00.000  Current
# 34             2024-05-20T00:00:00.000  Current
# 37             2024-12-31T00:00:00.000  Current
#
#                                                        closure  \
# disruption_id
# 32              Stony Plain Rd/149 St Reduced to 1 Lane Each W
# 34             156 St/Meadowlark Rd Reduced to 1 Lane Each Way
# 33                            87 Av Reduced to 1 Lane Each Way
# 34             156 St/Meadowlark Rd Reduced to 1 Lane Each Way
# 37                                87 Ave West LRT Construction
#
#                       on_street       from_street      to_street  \
# disruption_id
# 32             Stony Plain Road     139 Street NW  157 Street NW
# 34                156 Street NW  Stony Plain Road   87 Avenue NW
# 33                 87 Avenue NW     159 Street NW  182 Street NW
# 34                156 Street NW  Stony Plain Road   87 Avenue NW
# 37                 87 Avenue NW     170 Street NW  175 Street NW
#
#                       impact duration  \
# disruption_id
# 32             Travel Delays  2 Years
# 34             Travel Delays  2 Years
# 33             Travel Delays  2 Years
# 34             Travel Delays  2 Years
# 37             Travel Delays  3 Years
#
#                                                          details  \
# disruption_id
# 32             Stony Plain Rd, from 139 St - 157 St, and 149 ...
# 34             156 St/Meadowlark Rd will be reduced to 1 lane...
# 33             87 Av will be reduced to 1 lane in each direct...
# 34             156 St/Meadowlark Rd will be reduced to 1 lane...
# 37             The right lane of WB 87 Ave will remain closed...
#
#                          description activity_type traffic_district  \
# disruption_id
# 32                 WLRT Construction  Construction        Northeast
# 34                  LRT Construction  Construction        Northwest
# 33                  LRT Construction  Construction        Northwest
# 34                  LRT Construction  Construction        Northwest
# 37             West LRT Construction  Construction        Northwest
#
#                   infrastructure  \
# disruption_id
# 32                          Road
# 34             Road and Sidewalk
# 33                          Road
# 34             Road and Sidewalk
# 37             Road and Sidewalk
#
#                                                            point
# disruption_id
# 32             {'type': 'Point', 'coordinates': [-113.5920806...
# 34             {'type': 'Point', 'coordinates': [-113.5903322...
# 33             {'type': 'Point', 'coordinates': [-113.6371497...
# 34             {'type': 'Point', 'coordinates': [-113.5903262...
# 37             {'type': 'Point', 'coordinates': [-113.6153835...

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 32 to 1096
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_issued       120 non-null    object
#  1   start_date        120 non-null    object
#  2   finish_date       119 non-null    object
#  3   status            120 non-null    object
#  4   closure           120 non-null    object
#  5   on_street         120 non-null    object
#  6   from_street       119 non-null    object
#  7   to_street         108 non-null    object
#  8   impact            120 non-null    object
#  9   duration          118 non-null    object
#  10  details           120 non-null    object
#  11  description       120 non-null    object
#  12  activity_type     120 non-null    object
#  13  traffic_district  120 non-null    object
#  14  infrastructure    120 non-null    object
#  15  point             120 non-null    object
# dtypes: object(16)
# memory usage: 15.9+ KB

# %%
#Convert Date Columns to Datetime:
traffic_df['date_issued'] = pd.to_datetime(traffic_df['date_issued'])
traffic_df['start_date'] = pd.to_datetime(traffic_df['start_date'])
traffic_df['finish_date'] = pd.to_datetime(traffic_df['finish_date'])

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 32 to 1096
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_issued       120 non-null    datetime64[ns]
#  1   start_date        120 non-null    datetime64[ns]
#  2   finish_date       119 non-null    datetime64[ns]
#  3   status            120 non-null    object
#  4   closure           120 non-null    object
#  5   on_street         120 non-null    object
#  6   from_street       119 non-null    object
#  7   to_street         108 non-null    object
#  8   impact            120 non-null    object
#  9   duration          118 non-null    object
#  10  details           120 non-null    object
#  11  description       120 non-null    object
#  12  activity_type     120 non-null    object
#  13  traffic_district  120 non-null    object
#  14  infrastructure    120 non-null    object
#  15  point             120 non-null    object
# dtypes: datetime64[ns](3), object(13)
# memory usage: 15.9+ KB

# %%
# Drop rows with missing values
traffic_df.dropna(inplace=True)

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 32 to 1099
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_issued       105 non-null    datetime64[ns]
#  1   start_date        105 non-null    datetime64[ns]
#  2   finish_date       105 non-null    datetime64[ns]
#  3   status            105 non-null    object
#  4   closure           105 non-null    object
#  5   on_street         105 non-null    object
#  6   from_street       105 non-null    object
#  7   to_street         105 non-null    object
#  8   impact            105 non-null    object
#  9   duration          105 non-null    object
#  10  details           105 non-null    object
#  11  description       105 non-null    object
#  12  activity_type     105 non-null    object
#  13  traffic_district  105 non-null    object
#  14  infrastructure    105 non-null    object
#  15  point             105 non-null    object
# dtypes: datetime64[ns](3), object(13)
# memory usage: 13.9+ KB

# %%
#Extracting Information from 'Point' Column:
traffic_df['latitude'] = traffic_df['point'].apply(lambda x: x['coordinates'][1])
traffic_df['longitude'] = traffic_df['point'].apply(lambda x: x['coordinates'][0])

# %%
traffic_df.head(5)
# Out:
#               date_issued start_date finish_date   status  \
# disruption_id
# 32             2022-06-14 2022-06-20  2024-06-20  Current
# 34             2022-05-20 2022-05-20  2024-05-20  Current
# 33             2022-06-03 2022-04-19  2024-04-19  Current
# 34             2022-05-20 2022-05-20  2024-05-20  Current
# 37             2022-01-17 2021-07-27  2024-12-31  Current
#
#                                                        closure  \
# disruption_id
# 32              Stony Plain Rd/149 St Reduced to 1 Lane Each W
# 34             156 St/Meadowlark Rd Reduced to 1 Lane Each Way
# 33                            87 Av Reduced to 1 Lane Each Way
# 34             156 St/Meadowlark Rd Reduced to 1 Lane Each Way
# 37                                87 Ave West LRT Construction
#
#                       on_street       from_street      to_street  \
# disruption_id
# 32             Stony Plain Road     139 Street NW  157 Street NW
# 34                156 Street NW  Stony Plain Road   87 Avenue NW
# 33                 87 Avenue NW     159 Street NW  182 Street NW
# 34                156 Street NW  Stony Plain Road   87 Avenue NW
# 37                 87 Avenue NW     170 Street NW  175 Street NW
#
#                       impact duration  \
# disruption_id
# 32             Travel Delays  2 Years
# 34             Travel Delays  2 Years
# 33             Travel Delays  2 Years
# 34             Travel Delays  2 Years
# 37             Travel Delays  3 Years
#
#                                                          details  \
# disruption_id
# 32             Stony Plain Rd, from 139 St - 157 St, and 149 ...
# 34             156 St/Meadowlark Rd will be reduced to 1 lane...
# 33             87 Av will be reduced to 1 lane in each direct...
# 34             156 St/Meadowlark Rd will be reduced to 1 lane...
# 37             The right lane of WB 87 Ave will remain closed...
#
#                          description activity_type traffic_district  \
# disruption_id
# 32                 WLRT Construction  Construction        Northeast
# 34                  LRT Construction  Construction        Northwest
# 33                  LRT Construction  Construction        Northwest
# 34                  LRT Construction  Construction        Northwest
# 37             West LRT Construction  Construction        Northwest
#
#                   infrastructure  \
# disruption_id
# 32                          Road
# 34             Road and Sidewalk
# 33                          Road
# 34             Road and Sidewalk
# 37             Road and Sidewalk
#
#                                                            point   latitude  \
# disruption_id
# 32             {'type': 'Point', 'coordinates': [-113.5920806...  53.541294
# 34             {'type': 'Point', 'coordinates': [-113.5903322...  53.519453
# 33             {'type': 'Point', 'coordinates': [-113.6371497...  53.521606
# 34             {'type': 'Point', 'coordinates': [-113.5903262...  53.541293
# 37             {'type': 'Point', 'coordinates': [-113.6153835...  53.519548
#
#                 longitude
# disruption_id
# 32            -113.592081
# 34            -113.590332
# 33            -113.637150
# 34            -113.590326
# 37            -113.615384

# %%
#Convert Categorical Columns to Categorical Data Type:
traffic_df['status'] = traffic_df['status'].astype('category')

# %%
#Remove Unnecessary Columns:
traffic_df.drop(['point'], axis=1, inplace=True)

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 32 to 1099
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_issued       105 non-null    datetime64[ns]
#  1   start_date        105 non-null    datetime64[ns]
#  2   finish_date       105 non-null    datetime64[ns]
#  3   status            105 non-null    category
#  4   closure           105 non-null    object
#  5   on_street         105 non-null    object
#  6   from_street       105 non-null    object
#  7   to_street         105 non-null    object
#  8   impact            105 non-null    object
#  9   duration          105 non-null    object
#  10  details           105 non-null    object
#  11  description       105 non-null    object
#  12  activity_type     105 non-null    object
#  13  traffic_district  105 non-null    object
#  14  infrastructure    105 non-null    object
#  15  latitude          105 non-null    float64
#  16  longitude         105 non-null    float64
# dtypes: category(1), datetime64[ns](3), float64(2), object(11)
# memory usage: 14.2+ KB
